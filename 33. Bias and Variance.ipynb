# %% [markdown]
# # Bias and Variance

# %% [markdown]
# BIAS :- ΔTrain Error
#
# VARIANCE :- ΔTest Error

# %% [markdown]
# - Overfit models tend to have high variance
# - Underfit models tend to have high bias
